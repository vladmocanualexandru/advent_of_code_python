# %% [markdown]
# SETUP

# %%
import sys, os, math
import numpy as np
import pandas as pd
from functools import cmp_to_key

sys.path.append(os.path.abspath(os.path.join('../..')))

from utils import matrixUtils, arrayUtils, numberUtils, geometryUtils
from utils.inputDataUtils import *
from utils.stringOpUtils import *
from utils.terminalUtils import *
from utils.labelMakerUtils import *
from utils.solutionRoot import *

# %%
def getInputData(filename):
    data = getTuples_numbers(filename, ',')
    
    return data

# %% [markdown]
# EXAMPLE DATA

# %%
DATA_FILENAME = "example.data"

# %% [markdown]
# TEST DATA

# %%
DATA_FILENAME = "test.data"

# %% [markdown]
# PART 1

# %%
data = getInputData(DATA_FILENAME)
print(data[:10])
# Out:
# [[98389, 50440], [98389, 51653], [97975, 51653], [97975, 52871], [97981, 52871], [97981, 54078], [97799, 54078], [97799, 55291], [97711, 55291], [97711, 56472]]

# %%
def part1(data):
    mDists = []
    for a in range(len(data)-1):
        nodeA = data[a]
        for b in range(a+1, len(data)):
            nodeB = data[b]
            mDists.append((geometryUtils.getManhattanDistance(nodeA[0],nodeA[1],nodeB[0],nodeB[1]),a,b))

    mDists.sort(reverse=True)

    # print(mDists)
    largestRectangle = mDists[0]
    startNode = data[largestRectangle[1]]
    stopNode = data[largestRectangle[2]]

    # print(startNode)
    # print(stopNode)

    return (abs(startNode[0]-stopNode[0])+1)*(abs(startNode[1]-stopNode[1])+1)

result = part1(data)
print(yellow(result))
# Out:
# 4765757080

# %% [markdown]
# PART 2

# %%
dataPoints
# Out:
# [[7, 1],
#  [8, 1],
#  [9, 1],
#  [10, 1],
#  [11, 1],
#  [11, 2],
#  [11, 3],
#  [11, 4],
#  [11, 5],
#  [11, 6],
#  [11, 7],
#  [10, 7],
#  [9, 7],
#  [9, 6],
#  [9, 5],
#  [8, 5],
#  [7, 5],
#  [6, 5],
#  [5, 5],
#  [4, 5],
#  [3, 5],
#  [2, 5],
#  [2, 4],
#  [2, 3],
#  [3, 3],
#  [4, 3],
#  [5, 3],
#  [6, 3],
#  [7, 3],
#  [7, 2],
#  [7, 1]]

# %%
data = getInputData(DATA_FILENAME)

df = pd.DataFrame(data)

smallestX = min(df[1])
smallestXPos = int(df.index[df[1]==smallestX][0])

data = data[smallestXPos+1:] + data[0:smallestXPos+1]

[x,y] = data[-1]

dataPoints = []
dataPoints.append([x,y])

markers = []
markers.append([x,y-1])

for nextPoint in data:

    xRange = [x]
    yRange = [y]
    markerDeltaX = markerDeltaY = 0
    
    if y == nextPoint[1]: # left or right
        if x<nextPoint[0]: # right
            xRange = range(x, nextPoint[0]+1)
            markerDeltaY = -1
        else: # left
            xRange = range(x, nextPoint[0]-1, -1)
            markerDeltaY = 1
    else: #down or up
        if y<nextPoint[1]: # down
            yRange = range(y, nextPoint[1]+1)
            markerDeltaX = 1
        else: # up
            yRange = range(y, nextPoint[1]-1, -1)
            markerDeltaX = -1

    for x in xRange:
        for y in yRange:
            if [x,y]!=dataPoints[-1]:
                    dataPoints.append([x,y])
                    markers.append([x+markerDeltaX, y+markerDeltaY])
                
    markers = markers[:-1]

print(len(markers))
# # markerPoints
# Out:
# 588545

# %%
markersDf = pd.DataFrame(markers)

markersDf.loc[(markersDf[0] == 48082) & (markersDf[1] == 98140)].shape[0]!=0
# Out:
# True

# %%
def surface(a,b):
    return (abs(a[0]-b[0])+1)*(abs(a[1]-b[1])+1)

def pointInRectangle(x, a, b):
    return min(a[0],b[0]) < x[0] < max(a[0],b[0]) and min(a[1],b[1]) < x[1] < max(a[1],b[1]) 

def isRectangleValid(markersDf, a, b):
    for x in range(min(a[0],b[0])+1,max(a[0],b[0])):
        for y in range(min(a[1],b[1])+1,max(a[1],b[1])):
            if markersDf.loc[(markersDf[0] == x) & (markersDf[1] == y)].shape[0]!=0:
            # if hash(f"{x}_{y}") in markers:
                return False
    return True

# %%
surfaces = []
for ai in range(len(data)-1):
    for bi in range(ai+1, len(data)):
        a = data[ai]
        b = data[bi]

        surfaces.append((surface(a,b),a,b))

surfaces.sort(reverse=True)

# prevCoord = data[0]
# checkCoords = []
# for coord in data[1:]:
#     for x in range(min(prevCoord[0],coord[0]),max(prevCoord[0],coord[0])+1):
#         for y in range(min(prevCoord[1],coord[1]),max(prevCoord[1],coord[1])+1):
#             checkCoords.append([x,y])
#     # checkCoords.append([]+coord)
#     prevCoord=coord       

# for x in range(min(data[0][0],data[-1][0]),max(data[0][0],data[-1][0])+1):
#     for y in range(min(data[0][1],data[-1][1]),max(data[0][1],data[-1][1])+1):
#         checkCoords.append([x,y])


for si in range(len(surfaces)):
    s,a,b = surfaces[si]
    
    if si%100 == 0:
        print(si, len(surfaces))
        
    if isRectangleValid(markersDf,a,b):
        print("GOOD", a, b, s)
        break
    # else:
    #     print("BAD", a, b, surface)
        
# surfaces[:10]
# Out:
# 0 122760
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[196], line 31
#      28 if si%100 == 0:
#      29     print(si, len(surfaces))
# ---> 31 if isRectangleValid(markersDf,a,b):
#      32     print("GOOD", a, b, s)
#      33     break
#
# Cell In[194], line 10, in isRectangleValid(markersDf, a, b)
#       8 for x in range(min(a[0],b[0])+1,max(a[0],b[0])):
#       9     for y in range(min(a[1],b[1])+1,max(a[1],b[1])):
# ---> 10         if markersDf.loc[(markersDf[0] == x) & (markersDf[1] == y)].shape[0]!=0:
#      11         # if hash(f"{x}_{y}") in markers:
#      12             return False
#      13 return True
#
# File D:\Repositories\personal\advent-of-code\.venv\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ...

# %%
[98389, 50447] in checkCoords
# Out:
# True

# %%
def part2(data):
    result = 0

    return result

print(part2(data))

# %% [markdown]
# PROFILING

# %%
startTS = time.time()

data = getInputData(DATA_FILENAME)
dataTS = time.time()

part1Result = part1(data)
part1TS = time.time()

part2Result = part2(data)
part2TS = time.time()

dataElapsedMs = (dataTS-startTS)*1000
part1ElapsedMs = (part1TS-dataTS)*1000
part2ElapsedMs = (part2TS-part1TS)*1000

print(f"Data loaded in %.2fms" % dataElapsedMs)
print(f"Part 1 in %.2fms" % part1ElapsedMs)
print(f"Part 2 in %.2fms" % part2ElapsedMs)
print("Total: %.2fms" % (dataElapsedMs+part1ElapsedMs+part2ElapsedMs))
