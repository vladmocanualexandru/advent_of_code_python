# %% [markdown]
# SETUP

# %%
import sys, os, math
import numpy as np
import pandas as pd
from functools import cmp_to_key

sys.path.append(os.path.abspath(os.path.join('../..')))

from utils import matrixUtils, arrayUtils, numberUtils, geometryUtils
from utils.inputDataUtils import *
from utils.stringOpUtils import *
from utils.terminalUtils import *
from utils.labelMakerUtils import *
from utils.solutionRoot import *

# %%
def getInputData(filename):
    data = getTuples_numbers(filename,',')
    
    return data

# %% [markdown]
# EXAMPLE DATA

# %%
DATA_FILENAME = "example.data"
STEPS = 10

# %% [markdown]
# TEST DATA

# %%
DATA_FILENAME = "test.data"
STEPS = 1000

# %% [markdown]
# PART 1

# %%
data = getInputData(DATA_FILENAME)
print(data[:10])
# Out:
# [[96308, 96375, 66842], [52621, 1479, 29614], [79213, 87747, 77565], [22875, 9010, 68731], [58112, 11083, 91722], [24708, 5404, 6883], [45973, 8952, 70502], [21569, 42617, 95307], [91813, 29567, 46447], [91802, 14479, 55428]]

# %%
minDists = []

for i in range(len(data)-1):
    for j in range(i+1, len(data)):
        minDists.append((geometryUtils.get3DDistance(data[i], data[j]),i,j))

minDists.sort()

groupId = 0
grouping = [None for i in range(len(data))]

for _,a,b in minDists[:STEPS]:
    
    if grouping[a] == None:
        if grouping[b] == None:
            grouping[a] = grouping[b] = groupId
            groupId+=1
        else:
            grouping[a] = grouping[b]
    elif grouping[b] == None:
        grouping[b] = grouping[a]
    elif grouping[a]!=grouping[b]:
        targetGroupId = grouping[b]
        for gi in range(len(grouping)):
            if grouping[gi] == targetGroupId:
                grouping[gi] = grouping[a]

groupCounts = [0 for i in range(groupId)]
for gi in grouping:
    if gi!=None:
        groupCounts[gi]+=1

groupCounts.sort(reverse=True)
print(groupCounts[:10])

result = np.prod(groupCounts[:3])
print(yellow(int(result))) # 44100 < ...
# Out:
# [47, 36, 30, 30, 22, 22, 21, 16, 15, 15]
# 50760

# %%
def part1(data):
    result = 0

    return result

print(part1(data))

# %% [markdown]
# PART 2

# %%
minDists = []

for i in range(len(data)-1):
    for j in range(i+1, len(data)):
        minDists.append((geometryUtils.get3DDistance(data[i], data[j]),i,j,data[i][0],data[j][0]))

minDists.sort()

groupId = 1
grouping = [0 for i in range(len(data))]

result=None
for currentConnection in minDists:
    
    _,a,b,xA,xB = currentConnection
    if grouping[a] == 0:
        if grouping[b] == 0:
            grouping[a] = grouping[b] = groupId
            groupId+=1
        else:
            grouping[a] = grouping[b]
    elif grouping[b] == 0:
        grouping[b] = grouping[a]
    elif grouping[a]!=grouping[b]:
        targetGroupId = grouping[b]
        for gi in range(len(grouping)):
            if grouping[gi] == targetGroupId:
                grouping[gi] = grouping[a]

    if min(grouping) == max(grouping):
        result = xA * xB
        break

# result = np.prod(groupCounts[:3])
print(yellow(result)) # 44100 < ...
# Out:
# 3206508875

# %%
def part2(data):
    result = 0

    return result

print(part2(data))

# %% [markdown]
# PROFILING

# %%
startTS = time.time()

data = getInputData(DATA_FILENAME)
dataTS = time.time()

part1Result = part1(data)
part1TS = time.time()

part2Result = part2(data)
part2TS = time.time()

dataElapsedMs = (dataTS-startTS)*1000
part1ElapsedMs = (part1TS-dataTS)*1000
part2ElapsedMs = (part2TS-part1TS)*1000

print(f"Data loaded in %.2fms" % dataElapsedMs)
print(f"Part 1 in %.2fms" % part1ElapsedMs)
print(f"Part 2 in %.2fms" % part2ElapsedMs)
print("Total: %.2fms" % (dataElapsedMs+part1ElapsedMs+part2ElapsedMs))
