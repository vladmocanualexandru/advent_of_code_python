# %% [markdown]
# SETUP

# %%
import sys, os, math
import numpy as np
import pandas as pd

sys.path.append(os.path.abspath(os.path.join('../..')))

from utils import matrixUtils, arrayUtils, numberUtils, geometryUtils
from utils.inputDataUtils import *
from utils.stringOpUtils import *
from utils.terminalUtils import *
from utils.labelMakerUtils import *
from utils.solutionRoot import *

# %%
def getInputData(filename):
    data = getTuples_text(filename,'')
    
    return data

# %% [markdown]
# EXAMPLE DATA

# %%
originalData = getInputData("example.data")
logMatrix(originalData[:20])
# Out:
# .......S.......
# ...............
# .......^.......
# ...............
# ......^.^......
# ...............
# .....^.^.^.....
# ...............
# ....^.^...^....
# ...............
# ...^.^...^.^...
# ...............
# ..^...^.....^..
# ...............
# .^.^.^.^.^...^.
# ...............

# %% [markdown]
# TEST DATA

# %%
originalData = getInputData("test.data")
logMatrix(originalData[:20])
# Out:
# ......................................................................S......................................................................
# .............................................................................................................................................
# ......................................................................^......................................................................
# .............................................................................................................................................
# .....................................................................^.^.....................................................................
# .............................................................................................................................................
# ...

# %% [markdown]
# PART 1

# %%
part1Data = originalData

beamStatus = [False for i in range(len(part1Data[0]))]
startPos = matrixUtils.find(part1Data[:1], returnCondition=lambda e:e=='S')

beamStatus[startPos[0][1]] = True

result = 0
for line in part1Data[2:]:
    for beamSplit in matrixUtils.find(line, returnCondition=lambda e:e=='^'):
        splitPos = beamSplit[0]
        if beamStatus[splitPos]:
            result+=1
            beamStatus[splitPos-1] = True
            beamStatus[splitPos] = False
            beamStatus[splitPos+1] = True
    # print(matrixUtils.find(line, returnCondition=lambda e:e=='^'))
            
print(yellow(result))
# Out:
# 1602

# %%
part1Result = 0

print(part1Result)

# %% [markdown]
# PART 2

# %%
part2Data = originalData

print(part2Data[:10])

# %%
part2Result = 0

print(part2Result)
