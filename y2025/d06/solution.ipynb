# %% [markdown]
# SETUP

# %%
import sys, os, math, re
import numpy as np
import pandas as pd

sys.path.append(os.path.abspath(os.path.join('../..')))

from utils import matrixUtils, arrayUtils, numberUtils, geometryUtils
from utils.inputDataUtils import *
from utils.stringOpUtils import *
from utils.terminalUtils import *
from utils.labelMakerUtils import *
from utils.solutionRoot import *

# %%
def getInputData(filename):
    raw = getStrings(filename)

    data = []
    for line in raw[:-1]:
        data.append(re.split(r'\s+', line))

    numbers = pd.DataFrame(data).map(lambda e:int(e))
    ops = re.split(r'\s+', raw[-1])
    
    return (numbers, ops)

def getInputDataP2(filename):
    data = [line.replace("\n","") for line in getRawLines(filename)]

    return data

# %% [markdown]
# EXAMPLE DATA

# %%
originalData = getInputData("example.data")

# originalData

# %% [markdown]
# TEST DATA

# %%
originalData = getInputData("test.data")

# originalData[:10]

# %% [markdown]
# PART 1

# %%
(numbers, ops) = originalData

part1Result = 0

for i in range(len(ops)):
    if ops[i] == '+':
        part1Result += sum(numbers[i])
    else:
        part1Result += np.prod(numbers[i])

# print(yellow(part1Result))

# %% [markdown]
# PART 2

# %%
data = getInputDataP2("example.data")

# %%
data = getInputDataP2("test.data")

# %%
part2Result = 0

op = ''
opValue = 0
number = 0

for opIndex in range(len(data[-1])):
    if data[-1][opIndex] == '+': 
        opValue = 0
        op = '+'
    elif data[-1][opIndex] == '*':
        opValue = 1
        op = '*'

    number = 0 
    emptyColumn = True
    for digitIndex in range(len(data)-1):
        if data[digitIndex][opIndex] == ' ':
            continue
        emptyColumn = False
        number=number*10+int(data[digitIndex][opIndex])

    if emptyColumn:
        # print(opValue, op)
        part2Result+=opValue
    else:
        if op == '+':
            opValue+=number
        else:
            opValue*=number

    # print(number, op)
# print(opValue, op)

part2Result+=opValue


# print(yellow(part2Result))
