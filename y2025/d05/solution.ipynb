# %% [markdown]
# SETUP

# %%
import sys, os, math
import numpy as np
import pandas as pd

sys.path.append(os.path.abspath(os.path.join('../..')))

from utils import matrixUtils, arrayUtils, numberUtils, geometryUtils
from utils.inputDataUtils import *
from utils.stringOpUtils import *
from utils.terminalUtils import *
from utils.labelMakerUtils import *
from utils.solutionRoot import *

# %%
def getInputData(filename):
    allLines = getStrings(filename)

    ranges = []
    ids = None
    for line in allLines:
        if line.strip() == '':
            ids = []
            continue

        if ids == None:
            ranges.append([int(t) for t in line.split('-')])
        else:
            ids.append(int(line))
    
    return (ranges, ids)

# %% [markdown]
# EXAMPLE DATA

# %%
originalData = getInputData("example.data")

# %% [markdown]
# TEST DATA

# %%
originalData = getInputData("test.data")

# %% [markdown]
# PART 1

# %%
(ranges, ids) = originalData

part1Result = 0

for id in ids:
    for r in ranges:
        if id in range(r[0],r[1]+1):
            part1Result+=1
            break

print(yellow(part1Result))
# Out:
# 520

# %% [markdown]
# PART 2

# %%
ranges = []+originalData[0]

ranges.sort()

part2Result = 0
prevB = -1
for (a,b) in ranges:
    if a<=prevB and b<=prevB:
        continue

    if a<=prevB and b>prevB:
        part2Result-=prevB-a+1

    part2Result += b-a+1
    prevB = b

print(yellow(part2Result))
# Out:
# 347338785050515
