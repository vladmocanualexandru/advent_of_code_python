# %%
import sys, os, math
import numpy as np
import pandas as pd

sys.path.append(os.path.abspath(os.path.join('../..')))

from utils import matrixUtils, arrayUtils, numberUtils, geometryUtils
from utils.inputDataUtils import *
from utils.stringOpUtils import *
from utils.terminalUtils import *
from utils.labelMakerUtils import *
from utils.solutionRoot import *

# %%
def getInputData(inputFile):
    raw = getTuples_numbers(inputFile, '   ')

    return pd.DataFrame(raw)

# %%
# part 1
  
df = getInputData("test.data")

df[0] = np.sort(df[0])
df[1] = np.sort(df[1])

np.sum(df.apply(lambda e:abs(e.iloc[0]-e.iloc[1]), axis=1))

# result = np.sum(df.apply(abs(e.iloc[0]-e.iloc[1] for e in )))
# Out:
# 1603498

# %%
# part 2
df = getInputData("test.data")

# %%
np.sum(df.apply(lambda e: e[0]*np.sum(df[1]==e[0]), axis=1))
# Out:
# 25574739
